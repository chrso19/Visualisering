# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
data = pd.read_pickle("GBIF_data.pkl")

observations = data["observations"]
plants = data["plants"]

del data

# %%
key = plants.loc[plants['English name'] == "Wild garlic", 'taxonKey'].values[0]

fig = px.histogram(
    observations[np.logical_and(observations['taxonKey']==key, observations['year']==2024)],
    x='month',     
)

fig.show()
# Out:
#         taxonKey   eventDate  year  month  day  decimalLatitude  \
# 22       2857601  2023-05-23  2023      5   23        55.690550
# 47       2857601  2024-03-16  2024      3   16        55.683825
# 73       2857601  2025-04-11  2025      4   11        55.684671
# 100      2857601  2025-03-09  2025      3    9        56.794840
# 177      2857601  2023-05-13  2023      5   13        55.244931
# ...          ...         ...   ...    ...  ...              ...
# 113343   2857601  2024-05-04  2024      5    4        55.754147
# 113404   2857601  2024-04-24  2024      4   24        55.712152
# 113407   2857601  2024-04-06  2024      4    6        55.753219
# 113418   2857601  2025-04-26  2025      4   26        56.132806
# 113427   2857601  2025-05-01  2025      5    1        55.819387
#
#         decimalLongitude  coordinateUncertaintyInMeters      basisOfRecord  \
# 22             12.582911                          49.00  HUMAN_OBSERVATION
# 47             11.996670                          11.41  HUMAN_OBSERVATION
# 73             12.397702                           5.00  HUMAN_OBSERVATION
# 100             9.775106                          12.00  HUMAN_OBSERVATION
# 177            11.750905                          11.50  HUMAN_OBSERVATION
# ...                  ...                            ...                ...
# 113343         12.441385                          61.00  HUMAN_OBSERVATION
# 113404         12.355746                           9.49  HUMAN_OBSERVATION
# 113407         12.528359                           5.45  HUMAN_OBSERVATION
# 113418         10.136601                          24.00  HUMAN_OBSERVATION
# 113427         12.422771                          16.00  HUMAN_OBSERVATION
#
#                                   datasetKey  \
# 22      963a6b96-4d22-4428-86e4-afee52cf4a8e
# 47      963a6b96-4d22-4428-86e4-afee52cf4a8e
# 73      963a6b96-4d22-4428-86e4-afee52cf4a8e
# 100     963a6b96-4d22-4428-86e4-afee52cf4a8e
# 177     963a6b96-4d22-4428-86e4-afee52cf4a8e
# ...                                      ...
# 113343  963a6b96-4d22-4428-86e4-afee52cf4a8e
# 113404  963a6b96-4d22-4428-86e4-afee52cf4a8e
# 113407  963a6b96-4d22-4428-86e4-afee52cf4a8e
# 113418  963a6b96-4d22-4428-86e4-afee52cf4a8e
# 113427  963a6b96-4d22-4428-86e4-afee52cf4a8e
#
#                                               datasetName  \
# 22      Species recordings from the Danish National Po...
# 47      Species recordings from the Danish National Po...
# 73      Species recordings from the Danish National Po...
# 100     Species recordings from the Danish National Po...
# 177     Species recordings from the Danish National Po...
# ...                                                   ...
# 113343  Species recordings from the Danish National Po...
# 113404  Species recordings from the Danish National Po...
# 113407  Species recordings from the Danish National Po...
# 113418  Species recordings from the Danish National Po...
# 113427  Species recordings from the Danish National Po...
#
#                        recordedBy  individualCount  \
# 22      Páll Vang Kjærbo (privat)              NaN
# 47                     MaiaLinnet              NaN
# 73               mogens thornberg              NaN
# 100               Hans Micheelsen              NaN
# 177                 René Andersen              NaN
# ...                           ...              ...
# 113343              Frank Desting              NaN
# 113404           mogens thornberg              NaN
# 113407         Erik Aabjerg Friis              NaN
# 113418               Helene lycke              NaN
# 113427                 Stig Wedel              1.0
#
#                            occurrenceID      gbifID    license
# 22      https://arter.dk//fund/30731456  5893930863  CC_BY_4_0
# 47      https://arter.dk//fund/30915108  5893985218  CC_BY_4_0
# 73      https://arter.dk//fund/31401766  5893993783  CC_BY_4_0
# 100     https://arter.dk//fund/31323080  5893951413  CC_BY_4_0
# 177     https://arter.dk//fund/30617583  5894044774  CC_BY_4_0
# ...                                 ...         ...        ...
# 113343  https://arter.dk//fund/30963779  5893865163  CC_BY_4_0
# 113404  https://arter.dk//fund/30933152  5893925413  CC_BY_4_0
# 113407  https://arter.dk//fund/30938553  5893925433  CC_BY_4_0
# 113418  https://arter.dk//fund/31379806  5893897788  CC_BY_4_0
# 113427  https://arter.dk//fund/31418866  5894071098  CC_BY_4_0
#
# [553 rows x 16 columns]
